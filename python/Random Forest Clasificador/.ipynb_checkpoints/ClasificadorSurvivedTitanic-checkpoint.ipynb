# %% [markdown]
# ## Objetivo: Predecir supervivientes del titanic
#
# ### Replicar el clasificador del Kagle del
# [link](https://www.kaggle.com/code/sociopath00/random-forest-using-gridsearchcv/notebook)

# %%
# usamos los datos de titanic

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#Importamos scikit learn

from sklearn.model_selection import train_test_split #Split
from sklearn.model_selection import cross_val_score #cross validation
from sklearn.model_selection import GridSearchCV #grid search
from sklearn.ensemble import RandomForestClassifier #RF clasificador
from sklearn.metrics import accuracy_score #metricas de error
from sklearn.svm import SVC #
from scipy.stats import chi2_contingency #Para colinearidad entre categoricas

# %%
#Cargamos el archivo

titanic = pd.read_csv("Data/titanic.csv")
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#Analisis exploratorio

#Sexo

distr_sexo = titanic.groupby('Sex', as_index=False).size().rename({'size':'Cantidad'}, axis=1)

distr_sexo['%'] = ((distr_sexo['Cantidad']/distr_sexo['Cantidad'].sum())*100).round(2)

distr_sexo
# Out:
#       Sex  Cantidad      %
# 0  female       314  35.24
# 1    male       577  64.76

# %%
#Sobrevivientes

sobrev = titanic.groupby('Survived', as_index=False).size().rename({'size':'Cantidad'}, axis=1)
sobrev['%'] = ((sobrev['Cantidad']/sobrev['Cantidad'].sum())*100).round(2)
sobrev
# Out:
#    Survived  Cantidad      %
# 0         0       549  61.62
# 1         1       342  38.38

# %%
#graficamos los sobreviviente con seaborn

fig , ax = plt.subplots(figsize=(6,4))
sns.countplot(x='Survived', data=titanic)
plt.title("Cantidad de sobrevivientes")
plt.show()

# %%
#Reviso las variables de nuevo

titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#veo la matriz de correlacion de variables

#Cambio Pclass a categotica

titanic['Pclass'] = pd.Categorical(titanic['Pclass'])

titanic['Pclass'].dtypes


#Identificamos las variables entre numéricas y categoricas

cat=['Sex','Embarked','Pclass']
num=['Age','SibSp','Parch','Fare']
cat
num
# Out:
# ['Age', 'SibSp', 'Parch', 'Fare']

# %%
corr_df=titanic[num]  #New dataframe to calculate correlation between numeric features
cor= corr_df.corr(method='pearson')
print(cor)
# Out:
#             Age     SibSp     Parch      Fare
# Age    1.000000 -0.308247 -0.189119  0.096067
# SibSp -0.308247  1.000000  0.414838  0.159651
# Parch -0.189119  0.414838  1.000000  0.216225
# Fare   0.096067  0.159651  0.216225  1.000000

# %%
#Matriz de correlacion

fig, ax =plt.subplots(figsize=(8, 6))
plt.title("Correlation Plot")
sns.heatmap(cor, mask=np.zeros_like(cor, dtype=np.bool_), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax)
plt.show()

# %%
#Vemos colinearidad entre las variables categoricas
#usamos chi-cuadrado

#Empezamos por survived y sex

csq= chi2_contingency(pd.crosstab(titanic['Survived'], titanic['Sex']))
print("P-value: ",csq[1])
# Out:
# P-value:  1.1973570627755645e-58

# %%
# Survived y embarked

print("P-value: ",chi2_contingency(pd.crosstab(titanic['Survived'], titanic['Embarked']))[1])
# Out:
# P-value:  1.769922284120912e-06

# %%
# Survived y Pclass

print("P-value: ",chi2_contingency(pd.crosstab(titanic['Survived'], titanic['Pclass']))[1])
# Out:
# P-value:  4.549251711298793e-23

# %%
#Vemos la distribución de sobrevivientes y sexo

distr_survived = titanic.groupby(['Survived','Sex'],as_index=False).size()


distr_survived

fig, ax=plt.subplots(figsize=(8,6))
sns.countplot(x='Survived', data=titanic, hue='Sex')
ax.set_ylim(0,500)
plt.title("Impact of Sex on Survived")
plt.show()

# %%
fig, ax=plt.subplots(figsize=(8,6))
sns.countplot(x='Survived', data=titanic, hue='Pclass')
ax.set_ylim(0,500)
plt.title("Distribución de clase en los sobrevivientes")
plt.show()

# %%
fig, ax=plt.subplots(1,figsize=(8,6))
sns.boxplot(x='Survived',y='Fare', data=titanic)
ax.set_ylim(0,300)
plt.title("Sobrevivientes vs Tarifa")
plt.show()

# %%
#Manejo de missing

print(titanic.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
#Reemplazamos los NA con la mediana

prom_age = np.nanmedian(titanic['Age'])

titanic['Age'] = titanic['Age'].fillna(prom_age)

titanic['Age'].describe()
# Out:
# count    891.000000
# mean      29.361582
# std       13.019697
# min        0.420000
# 25%       22.000000
# 50%       28.000000
# 75%       35.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
# Vemos la variable cabin

titanic['Cabin'].value_counts()

titanic['Cabin'] = titanic['Cabin'].fillna(0)
# Out:
# 0              687
# G6               4
# B96 B98          4
# C23 C25 C27      4
# F33              3
#               ...
# D9               1
# C82              1
# E40              1
# A34              1
# T                1
# Name: Cabin, Length: 148, dtype: int64

# %% [markdown]
# # Feature Engineering

# %%
#Creamos una nueva variable para cabin, asigna 0 a 0 y 1 al resto

titanic['hasCabin']=titanic['Cabin'].apply(lambda x: 0 if x==0 else 1)
# Out:
# 0    687
# 1    204
# Name: hasCabin, dtype: int64

# %%
#Cominamos 'SibSp' y 'Parch' para crear la variable FamilyMem

titanic['FamilyMem']=titanic.apply(lambda x: x['SibSp']+x['Parch'], axis=1)
# Out:
# 0     537
# 1     161
# 2     102
# 3      29
# 5      22
# 4      15
# 6      12
# 10      7
# 7       6
# Name: FamilyMem, dtype: int64
