# %% [markdown]
# ## Objetivo: a partir de los datos de ventas de libros proyectar las ventas del proximo mes

# %%
# Importo las librerias

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Cargo el dataset

df = pd.read_excel("Data/data.xlsx",  skiprows = 1,usecols = 'C:AU')

# %%
df
# Out:
#          TITLE     AUTHOR     LABEL             DIVISION LAUCNCH DATE  \
# 0      Libro 1    Autor 1   GRJ-020            COMERCIAL   1999-01-01
# 1      Libro 2    Autor 2   AGL-021            COMERCIAL   2009-11-01
# 2      Libro 3    Autor 3   ALF-022            LITERARIA   2010-09-01
# 3      Libro 4    Autor 4   DEB-023             BOLSILLO   2011-05-01
# 4      Libro 5    Autor 5   DEB-023             BOLSILLO   2011-05-01
# ..         ...        ...       ...                  ...          ...
# 651  Libro 653  Autor 653  ALFJ-025  INFANTIL Y JUVENIL    2018-12-01
# 652  Libro 654  Autor 654  ALFI-031  INFANTIL Y JUVENIL    2018-12-01
# 653  Libro 655  Autor 655   LUM-030            LITERARIA   2018-12-01
# 654  Libro 656  Autor 656  ROCI-028  INFANTIL Y JUVENIL    2018-12-01
# 655  Libro 657  Autor 657   LIT-034            LITERARIA   2018-12-01
#
#                     SEGMENT   TYPE  PVP   Ener    Feb  ...  Abr.2  May.2  \
# ...

# %%
#Creo un vector de secuencia de fechas mensuales

import datetime

#Vector de meses
meses = pd.date_range('1/1/2018', periods = 37, freq ='M').strftime("%Y-%m-%d").tolist()

#Nombre del resto de las columnas
columnas = ['TITLE','AUTHOR','LABEL','DIVISION','LAUCNCH DATE','SEGMENT','TYPE','PVP']

#Concateno las listas
labels = np.concatenate([columnas,meses])

#Renombro el data frame
df.columns = labels

df.head()
# Out:
#      TITLE   AUTHOR    LABEL   DIVISION LAUCNCH DATE                 SEGMENT  \
# 0  Libro 1  Autor 1  GRJ-020  COMERCIAL   1999-01-01  AUTOAYUDA Y SUPERACIÓN
# 1  Libro 2  Autor 2  AGL-021  COMERCIAL   2009-11-01               AUTOAYUDA
# 2  Libro 3  Autor 3  ALF-022  LITERARIA   2010-09-01     BIBLIOTECA SARAMAGO
# 3  Libro 4  Autor 4  DEB-023   BOLSILLO   2011-05-01           CONTEMPORÁNEA
# 4  Libro 5  Autor 5  DEB-023   BOLSILLO   2011-05-01           CONTEMPORÁNEA
#
#     TYPE  PVP  2018-01-31  2018-02-28  ...  2020-04-30  2020-05-31  \
# 0  FONDO  259        17.0         9.0  ...          18          19
# 1  FONDO  239        13.0        18.0  ...           5           0
# 2  FONDO  329       133.0       122.0  ...          31           9
# 3  FONDO  209       161.0       115.0  ...          43          43
# 4  FONDO  209        68.0        86.0  ...          34          73
#
#    2020-06-30  2020-07-31  2020-08-31  2020-09-30  2020-10-31  2020-11-30  \
# ...

# %%
#hago un melt con el data frame

df = df.melt(id_vars= columnas, var_name= "Fecha",value_name= "Cantidad")

df
# Out:
#            TITLE     AUTHOR     LABEL             DIVISION LAUCNCH DATE  \
# 0        Libro 1    Autor 1   GRJ-020            COMERCIAL   1999-01-01
# 1        Libro 2    Autor 2   AGL-021            COMERCIAL   2009-11-01
# 2        Libro 3    Autor 3   ALF-022            LITERARIA   2010-09-01
# 3        Libro 4    Autor 4   DEB-023             BOLSILLO   2011-05-01
# 4        Libro 5    Autor 5   DEB-023             BOLSILLO   2011-05-01
# ...          ...        ...       ...                  ...          ...
# 24267  Libro 653  Autor 653  ALFJ-025  INFANTIL Y JUVENIL    2018-12-01
# 24268  Libro 654  Autor 654  ALFI-031  INFANTIL Y JUVENIL    2018-12-01
# 24269  Libro 655  Autor 655   LUM-030            LITERARIA   2018-12-01
# 24270  Libro 656  Autor 656  ROCI-028  INFANTIL Y JUVENIL    2018-12-01
# 24271  Libro 657  Autor 657   LIT-034            LITERARIA   2018-12-01
#
#                       SEGMENT   TYPE  PVP       Fecha  Cantidad
# ...

# %%
df['Fecha'] = pd.to_datetime(df['Fecha'])

df['Cantidad'] = df['Cantidad'].fillna(0)

df.isnull().sum()
# Out:
# TITLE           0
# AUTHOR          0
# LABEL           0
# DIVISION        0
# LAUCNCH DATE    0
# SEGMENT         0
# TYPE            0
# PVP             0
# Fecha           0
# Cantidad        0
# dtype: int64

# %%
#Visalizamos la serie de tiempo en general


df_agrupado = df.groupby('Fecha', as_index=False).sum('Cantidad')


fig, ax = plt.subplots(figsize=(8,4))

plt.plot(df_agrupado["Fecha"], df_agrupado["Cantidad"])
plt.show()

# %%
#Agregamos la columa mes, quarter, year


df_agrupado['Mes'] = pd.DatetimeIndex(df_agrupado['Fecha']).month
df_agrupado['Anio'] = pd.DatetimeIndex(df_agrupado['Fecha']).year
df_agrupado['Trim'] = pd.DatetimeIndex(df_agrupado['Fecha']).quarter

df_agrupado= df_agrupado.sort_index()

# %%
#Vemos estacionalidad con valores inferiores a enero 2021

fig1, ax = plt.subplots(3, figsize=(15, 6))

plt.suptitle('')
ax[0].set_xlabel("")
ax[1].set_xlabel("")
ax[2].set_xlabel("")

boxprops = dict(linestyle='-', linewidth=2.5, color='#2110e3')
medianprops = dict(linestyle='-', linewidth=2.5, color='#e310b2')

df_agrupado.query("Fecha < '2022-01-01'").boxplot(column=['Cantidad'], by= 'Mes', ax=ax[0],
                 showfliers=False, showmeans=False,boxprops=boxprops,medianprops=medianprops)

df_agrupado.query("Fecha < '2022-01-01'").boxplot(column=['Cantidad'], by= 'Anio', ax=ax[1],
                                                 boxprops=boxprops,medianprops=medianprops)

df_agrupado.query("Fecha < '2022-01-01'").boxplot(column=['Cantidad'], by= 'Trim', ax=ax[2],
                                                 boxprops=boxprops,medianprops=medianprops)
# Out:
# <AxesSubplot:title={'center':'Cantidad'}, xlabel='Trim'>

# %%
#Armo el dataset para el forecast

st_libros = df.groupby(["TITLE","Fecha"],as_index=False).sum("Cantidad")
