# %% [markdown]
# Cuando nuestros datos no tienen etiquetas (por ejemplo 0= Sano, 1= Enfermo), podemos buscar patrones mediante el algoritmos de **Aprendizaje no supervisado**. En esta notebook voy a utilizar K-Means y K-Means Mini-Batch para agrupar los datos de flores del dataset **Iris**. Asimismo, veremos que la bondad del modelo y una comparación de la eficiencia en tiempo lograda con K-Means Mini Batch.

# %%
#Importamos las librerias y el dataset iris

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn import datasets
from sklearn import metrics


#Importamos Iris
iris = datasets.load_iris()

#Convertimos Iris en un data frame de pandas
df = pd.DataFrame(data= np.c_[iris['data'], iris['target']],
                     columns= iris['feature_names'] + ['target'])
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0       0.0
# ...

# %%
#Seleccionamos sepal length (cm) y sepal width (cm) y observamos como se distribuyen entre estas
# dos variables las especies de flores.


fig = plt.figure(figsize =(6,6))

viridis = plt.cm.get_cmap('viridis', 3)

legend = [
    plt.scatter([], [], marker='o', label= 'setosa', edgecolors = viridis(0), c=viridis(0)),
    plt.scatter([], [], marker='o', label='versicolor', edgecolors = viridis(1), c=viridis(1)),
    plt.scatter([], [], marker='o', label='virginica', edgecolors = viridis(2), c=viridis(2))
]


plt.scatter(df['sepal length (cm)'],df['sepal width (cm)'], c= df['target'], cmap= 'viridis')
plt.xlabel('sepal length (cm)')
plt.ylabel('sepal width (cm)')
plt.legend(handles=legend, loc='upper right', ncol=3)
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# ## Aplicamos el modelo Kmeans

# %%
#Importamos las librerias:
# time para medir el tiempo de ejecución del script
# metrics para obtener la bondad del ajuste del modelo
import time
from sklearn import metrics


# Guardamos en un objeto los datos sin target

x = df.drop(['target'], axis= 1)
x
# plantamos una semilla aleatoria

np.random.seed(123)

#Instanciamos el modelo

model_k_means = KMeans(n_clusters=3, max_iter=2000) 

#Instanciamos el momento 0
t0 = time.time()

#Entrenamos el modelo
model_k_means.fit(x)

#Capturamos el tiempo luego de entrenar el modelo menos el momento 0
t_batch = time.time() - t0


print("-------------------------")
print("---Tiempo de ejecución---")
print("-------",round(t_batch,2),"--------")
print("-------------------------")

#Generamos las predicciones

pred_k_means = model_k_means.predict(x)

#Obtenemos las métricas de error

score=metrics.adjusted_rand_score(df['target'], pred_k_means)

print("-----------------------------")
print("------Indice Rand------------")
print("El score obtenido es: ",round(score,3))
print("-----------------------------")
# Out:
# -------------------------
# ---Tiempo de ejecución---
# ------- 0.05 --------
# -------------------------
# -----------------------------
# ------Indice Rand------------
# El score obtenido es:  0.73
# -----------------------------

# %%
#Creamos un gráfico para mostrar el agrupamiento original y el agrupamiento producto de K-means

fig, ax = plt.subplots(1,2, figsize=(15,10))
ax[0].set_title("Original")
ax[1].set_title("Kmeans")

#Creamos la paleta con una escala de 3 colores
viridis = plt.cm.get_cmap('viridis', 3)

#Instancio las leyendas
legend = [
    plt.scatter([], [], marker='o', label= 'setosa', edgecolors = viridis(0), c=viridis(0)),
    plt.scatter([], [], marker='o', label='versicolor', edgecolors = viridis(1), c=viridis(1)),
    plt.scatter([], [], marker='o', label='virginica', edgecolors = viridis(2), c=viridis(2))
]



ax[0].scatter(df['sepal length (cm)'],df['sepal width (cm)'], c= df['target'].values, cmap= 'viridis')
ax[0].legend(handles=legend, loc='upper right', ncol=3)

ax[1].scatter(x['sepal length (cm)'],x['sepal width (cm)'], c= pred_k_means, cmap= 'viridis')
ax[1].legend(handles=legend, loc='upper right', ncol=3)
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# #### Comentarios
#
#  - Una limitación de estos gráficos es que sólo podemos graficar dos dimensiones. Una buena estrategia podría ser aplicar un Análisis de la Componente Principal (PCA) y reducir la dimensionalidad del conjunto de datos de Iris a 2.
#
#  - El **Índice Rand Ajustado** es una medida de similitud entre dos agrupamiento, la documentación de scikit-learn explica:
#  > *El índice de Rand calcula una medida de similitud entre dos agrupamientos considerando todos los pares de muestras y contando los pares que se asignan en el mismo o en diferentes agrupamientos en los agrupamientos predichos y verdaderos.*
#
#  Toma valores entre 0 y 1, siendo 1 cuando las agrupaciones son idénticas.
#
#  - Además de un índice Rand alto, los gráficos de la distribución original del dataset IRIS y del agrupado pr K-means dan cuenta del buen ajuste obtenido.
#
#  - Ahora bien, en muchas ocasiones no contamos con las etiquetas que nos permitan establecer a priri los agrupamientos, por lo que no es posible utilizar el índice de Rand.
#
#  =================================================================================================

# %% [markdown]
# ### Estrategias para definir la cantidad de agrupamientos (parámetro K) cuando no contamos con las etiquetas verdaderas
#
# - Para este escenario describiremos dos estrategias que podemos implementar:
#     - **Metodo Elbow o "Codo"**: consiste en probar un rango del hiperparámetro K hasta que la varianza total intra cluster apenas muestra mejoría.
#     - **Metodo Silhoutte**: El coeficiente de Silhoutte mide la distancia entre grupos frente a la distancia dentro de los grupos. Una puntuación más alta significa clústeres mejor definidos. Su valor puede estar entre -1 y 1, siendo valores próximos a 1 un indicativo de que la observación se ha asignado al cluster correcto.

# %%
# Metodo Elbow o "Codo"

n_cluster = range(1,15)
inercia = []

for cluster in n_cluster:
    kmeans_elbow = KMeans(n_clusters= cluster, max_iter=200, random_state=123) 
    kmeans_elbow.fit(x)
    inercia.append(kmeans_elbow.inertia_)    

fig, ax = plt.subplots(1, 1, figsize=(6, 3.84))
ax.plot(n_cluster, inercia, marker='o')
ax.set_title("Evolución de la varianza intra-cluster total")
ax.set_xlabel('Número clusters')
ax.set_ylabel('Intra-cluster (inertia)')
# Out:
# Text(0, 0.5, 'Intra-cluster (inertia)')

# %%
# Metodo Silhouette

n_cluster = range(2,15) #Aqui partimos de 2 porque Silhouette requiere más de 1 etiquetas de clúster 
score = []

for cluster in n_cluster:
    kmeans_model = KMeans(n_clusters= cluster, max_iter=200, random_state=123) 
    kmeans_model.fit(x)
    cluster_predichos = kmeans_model.predict(x)
    indice_silhouette = metrics.silhouette_score(x,cluster_predichos, metric='euclidean')
    score.append(indice_silhouette)  
    

fig, ax = plt.subplots(1, 1, figsize=(6, 3.84))
ax.plot(n_cluster, score, marker='o')
ax.set_title("Evolución del score silhouette")
ax.set_xlabel('Número clusters')
ax.set_ylabel('Media del indice silhouette')
# Out:
# Text(0, 0.5, 'Media del indice silhouette')

# %% [markdown]
# ### Comentarios
#
# - Si nos guíamos por el primer método podríamos decir que a partir de K= 3 la inercia parecería estabilizarse.
# - En el caso del **método silhouette**, en cambio, el número óptimo de clústeres es 2.

# %% [markdown]
# ## Implementamos el modelo K-means Mini Batch

# %%
# importamos el modelo de la libreria cluster

from sklearn.cluster import MiniBatchKMeans
from sklearn import metrics
import time

#plantamos una semilla aleatoria

np.random.seed(123)


#Instanciamos el momento 0
t1 = time.time()

#Instanciamos el mismo modelo pero Mini batches

k_means_mb = MiniBatchKMeans(n_clusters=3, max_iter=2000)

#Capturamos el tiempo luego de entrenar el modelo menos el momento 0
t_batch_1 = time.time() - t1

print("-------------------------")
print("---Tiempo de ejecución---")
print("---------",round(t_batch_1,2),"----------")
print("-------------------------")

#Entrenamos el modelo tulizando los datos escalados

k_means_mb.fit(x)

#Creamos las predicciones del modelo

pred_k_means_mb = k_means_mb.predict(x)

#Obtenemos las métricas de error

score_mb= metrics.adjusted_rand_score(df['target'], pred_k_means_mb)

print("-----------------------------")
print("------Indice Rand------------")
print("El score obtenido es: ",round(score_mb,3))
print("-----------------------------")

#Graficamos las predicciones


plt.scatter(x['sepal length (cm)'],x['sepal width (cm)'], c= pred_k_means_mb, cmap= 'viridis')

plt.show()
# Out:
# -------------------------
# ---Tiempo de ejecución---
# --------- 0.0 ----------
# -------------------------
# -----------------------------
# ------Indice Rand------------
# El score obtenido es:  0.716
# -----------------------------

# %% [markdown]
# ### Comentarios
#
#  - Podemos observar que el modelo K-Means Mini Batch nos permite agrupar los datos en cluster con una menor precisión que K-means (score 0.73 vs 0.716). Ahora bien, desde el punto de vista del tiempo de ejecución obtenido con la __libreria time__, podemos observar que el modelo K-means tardo 0.5 s y el modelo K-means Mini Batch tarda 0.0 s.
#  - En conclusión, el modelo __K-means Mini Batch__ es más __eficiente__ obteniendo métricas de error solo __levemente mayores__ al __modelo K-means__.
